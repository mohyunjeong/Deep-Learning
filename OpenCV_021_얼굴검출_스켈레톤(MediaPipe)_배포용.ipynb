# %% [markdown]
# <center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/00_title.png"></center>

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:30px; text-align: center;"><font size=4 color=blue><b>[21차시] 학습목표</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>
#
# ○ Mediapipe 라이브러리를 활용할 수 있다 <br><br>
# ○ Mediapipe 라이브러리를 이용하여 얼굴 특성을 추출할 수 있다 <br><br>
# ○ Mediapipe 라이브러리를 이용하여 동작 특성을 추출할 수 있다 </font></td></tr>
# </table>

# %% [markdown]
# # Mediapipe 라이브러리를 이용한 얼굴 3D 데이터 추출

# %% [markdown]
# - 라이브 및 스트리밍 미디어를 위한 플랫폼 간 사용자 지정 가능한 ML 솔루션을 제공
# - mediapipe 라이브러리 : https://google.github.io/mediapipe/getting_started/python
# - 기능
# <table width=800>
#     <tr>
#         <td><center><b>얼굴 검출</b></center></td>
#         <td><center><b>얼굴 Mesh</b></center></td>
#         <td><center><b>홍채 검출</b></center></td>
#         <td><center><b>손동작 검출</b></center></td>
#         <td><center><b>동작 검출</b></center></td>
#         <td><center><b>전체동작</b></center></td>
#     </tr>
#     <tr>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_face_detection.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_face_mesh.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_iris_tracking.gif "></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_hand_tracking.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_pose_tracking.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_holistic_tracking.gif"></center></td>
#     </tr>
#     <tr>
#         <td><center><b>헤어 분리</b></center></td>
#         <td><center><b>객체 검출</b></center></td>
#         <td><center><b>박스 추적</b></center></td>
#         <td><center><b>모션 추적</b></center></td>
#         <td><center><b>3D객체 검출</b></center></td>
#         <td><center><b>템플릿 매칭</b></center></td>
#     </tr>
#     <tr>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_hair_segmentation.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_object_detection.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_box_tracking.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_instant_motion_tracking.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_objectron_chair.gif"></center></td>
#         <td><center><img src="https://arome1004.cafe24.com/images/opencv/lecture_image/21_mediapipe_template_matching.gif"></center></td>
#     </tr>
# </table>

# %%
# 프롬프트 창에서 설치
# !pip install mediapipe

# %%
import cv2
import mediapipe as mp

# No module named 'mediapipe'가 뜨는 경우
#   - 설치 폴더 (아래 설치내용 확인) 확인해서 .\anaconda3\envs\gpu\lib\site-packages로 이동

# No module named 'mediapipe.python._framework_bindings가 뜨는 경우
#   -

# %% [markdown]
# ## 얼굴 메시 추출

# %%
#실습

# %% [markdown]
# ## 얼굴, 왼손, 오른손, 동작 검출 (스켈레톤)

# %%
#실습

# %% [markdown]
# <table border=1 width=100%>
#     <tr><td style="border: 1px solid black; width:600px; height:40px; text-align: center;"><font size=4 color=blue><b>[21차시] 정리하기</b></font></td></tr>
#     <tr><td style="border: 1px solid black; text-align: left;"><font size=3>○
#         </font></td></tr>
# </table>
